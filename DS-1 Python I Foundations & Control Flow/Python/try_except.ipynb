# %% [markdown]
# #### Try and Except
#
# - try: Execute the block of code that might cause exception
# - except: Do this part if there was an exception
# - else: Do this part if there was NOT an exception
# - finally: Do this part no matter what happens

# %%
print('Welcome to the Mortgage Calculator')
try:
    salary = int(input('What is your salary? '))
except:
    print('Please, enter an integer')
    salary = int(input('What is your salary? '))
else:
    rate = 0

    if salary >= 2000:
        print('You are eligible for mortgage!')
        credit_score = int(input('What is your credit score' ))
        if credit_score > 800:
            rate = 4
            print('Interest rate: 4%')
        elif credit_score > 750:
            rate = 6
            print('Interest rate: 6%')
        else:
            rate = 8
            print('Interest rate: 8%')
        disability = input('Do you have disability? [Y, N] ')
        if disability == 'Y':
            rate = 2
            print(f'Final interest rate {rate}%')
    else:
        print('Sorry, you are not eligible')
finally:
    print('Thanks for using our calculator')
# Out:
# Welcome to the Mortgage Calculator
# What is your salary? e
# Please, enter an integer
# What is your salary? 4321
# Thanks for using our calculator

# %% [markdown]
# #### Project - Gross pay with exception
# Rewrite Gross Pay program using try and except so that your program handles non-numeric input gracefully by printing a message and exiting the program.

# %%
try:
    hour = float(input('Enter hour: '))
except ValueError:
    print('Error, please enter a numeric value for hour')
    quit()
try:
    rate = float(input('Enter rate: '))
except ValueError:
    print('Error, please enter a numeric value for rate')
    quit()

if hour < 40:
    pay = hour * rate
else:
    overtime = hour - 40
    pay = 40 * rate + overtime * rate * 1.5

print(f"Your gross pay is ${pay:.2f}")
# Out:
# Enter hour: 48
# Enter rate: 3
# Your gross pay is $156.00

# %% [markdown]
# ## Project 10 - Score Checker
#
# # Instructions
#
# Write a program to prompt for a score between 0.0 and 1.0. If the
# score is out of range, print an error message. If the score is between 0.0 and
# 1.0, print a grade using the following table:
#
#
# Grade | Score |
# --- | --- |
# A | >= 0.9 |
# B | >= 0.8 |
# C | >= 0.7 |
# D | >= 0.6 |
# F | < 0.6 |

# %%
try:
    score = float(input("Enter a score: "))
except ValueError:
    print('Bad score')
    quit()

if score >= 0.0 and score <= 1.0:
    if score >= 0.9:
        print("A")
    elif score >= 0.8:
        print("B")
    elif score >= 0.7:
        print("C")
    elif score >= 0.6:
        print("D")
    else:
        print("F")
else:
    print("Bad score")
# Out:
# Enter a score: .75
# C

# %%
# Out:
# 0
