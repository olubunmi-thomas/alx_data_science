# %% [markdown]
# #### Input Function
# - The `input()` function in python allows the user type something that goes in a Python variable. Whatever the user enter as input, the `input()` function converts it into a string. It is possible to cast the data type of the input to what we want.

# %%
a = input()
print(type(a))
# Out:
# 5.7
# <class 'str'>

# %% [markdown]
# ### Task
# Write a program that uses input to prompt a user for their name and then prints to the console the number of characters in the inputed name.

# %%
# Write your code here
name = input('Please, can you enter your name? ')
length = len(name)
print(f"Your name has {length} characters")
# Out:
# Please, can you enter your name? Solomon
# Your name has 7 characters

# %%
one = '1'
one = float(one)  # Typecasting
type(one)
# Out:
# float

# %% [markdown]
# ### Task
# Write a program that uses input to prompt a user to enter a number and then print Odd if the number is `odd` and Even if the number is `even`.

# %%
# @title
number = int(input('Enter an integer: '))

if number % 2 != 0:
    print(f'{number} is an Odd number')
else:
    print(f'{number} is an Even number')
# Out:
# Enter an integer: 47
# 47 is an Odd number

# %% [markdown]
# #### Task
# Write a program that prompt a user to enter his name and then print `Hello name`.

# %%
name = input('What is your name?')
message = f"Hello {name}"
print(message)
# Out:
# What is your name?Mark
# Hello Mark

# %% [markdown]
# #### Task
# - Write a program that prompt the user to enter two different strings and then concatenate them.
#
# - **Example:**
#   - string1 = 'face'
#   - string2 = 'book
#
# - string = facebook

# %%
string1 = input('Enter the first string ')
string2 = input('Enter the second string ')

string = f"{string1}{string2}"
print(string)
# Out:
# Enter the first string face
# Enter the second string book
# facebook

# %% [markdown]
# #### Task
# - Write a program that converts number of years to the weeks.
# - if the input was 2, then the output should be 2 * 52 = 104, because we have 52 weeks in 1 year.

# %%
years = int(input("Enter number of years "))
weeks = 52 * years
print(f"There are {weeks} weeks in {years} years")
# Out:
# Enter number of years 4
# There are 208 weeks in 4 years

# %% [markdown]
# ### Project 1
# - Write a program that uses input to prompt a user for their name and then welcomes them.
#
# **For Example:**
# - name = 'Paulina'
#
# Hello Paulina!
#
# Welcome to the Python class.

# %%
# @title
name = input('What is your name? ')
message = f"Hello {name}!\nWelcome to the Python class"
print(message)
# Out:
# What is your name? Chloe
# Hello Chloe!
# Welcome to the Python class

# %% [markdown]
# #### Project 2 - Group Name Generator
# - Create a greeting for your program
# - Ask the user for their favorite color
# - Ask the user for their favorite animal
# - Combine their favorite color and favorite animal and show them their group name.

# %%
# @title
print('Welcome to the group name generator.')
color = input('What is your favorite color? ')
animal = input('What is your favorite animal? ')
group_name = f"Your group name could be {color} {animal}s."
print(group_name)
# Out:
# Welcome to the group name generator.
# What is your favorite color? White
# What is your favorite animal? Wolve
# Your group name could be White Wolves.

# %% [markdown]
# ### Project 3 - Gross Pay
# - Write a program to prompt the user for hours and rate per hour to compute gross pay.
# - You need to take into account that your output must be in two decimal places.

# %%
# @title
hours = int(input('Enter hours: '))
rate = float(input('Enter rate: '))
pay = hours * rate
print(f"Your gross pay is ${pay:.2f}")
# Out:
# Enter hours:  4
# Enter rate:  3.5
# Your gross pay is $14.00

# %% [markdown]
# #### Project 4 - Celcius to Fahrenheit
# - Write a program which prompts the user for a Celsius temperature.
# - Convert the temperature to Fahrenheit,
# - and print out the converted temperature.
#
# Formula : (°C × 9/5) + 32 = °F

# %%
# @title
celcius = int(input('Enter Temperature in Celsius: '))
fahrenheit = int((celcius * 9/5) + 32)
output = f"{celcius} Celsius = {fahrenheit} Fahrenheit"
print(output)
# Out:
# Enter Temperature in Celsius: 4
# 4 Celsius = 39 Fahrenheit

# %% [markdown]
# #### Project 5 - Trip Cost Calculator
# Write a program which calculates trip cost for a user.
# 1. Create a greeting for your program.
# 2. Ask the user for number of days.
# 3. Ask the user for hotel price.
# 4. Ask the user for flight price.
# 5. Ask the user for rental car price.
# 6. Ask for other expenses, put $0 if none.
# 7. Combine all expenses together and print with 2 digits after decimal places.
#
# - Note: All the prices must contain $

# %%
# @title
print('Welcome to the Trip Cost Calculator!')
days = int(input('How many days will you stay? $'))
hotel_price = float(input('How much does hotel cost per night? $'))
flight_price = float(input('How much does flight cost? $'))
car_price = float(input('If you need rental car please enter the price otherwise enter zero $'))
other_expenses = float(input('Enter other possible expenses $'))
total_expenses = (days * hotel_price) + flight_price + days*car_price + other_expenses
print(f"Total Cost: ${total_expenses:.2f}")
# Out:
# Welcome to the Trip Cost Calculator!
# How many days will you stay? $3
# How much does hotel cost per night? $30
# How much does flight cost? $50
# If you need rental car please enter the price otherwise enter zero $10
# Enter other possible expenses $0
# Total Cost: $170.00

# %% [markdown]
# #### Task
# -

# %%
name = input("Enter your name: ")
print("Hello, " + name + ". Nice to meet you!")
 
print("\nPress Enter to end the program.")
input()
print("THE END.")
# Out:
# Enter your name:  Thomas
# Hello, Thomas. Nice to meet you!
#
# Press Enter to end the program.
# THE END.

# %% [markdown]
# #### Task
#
# Your task is to prepare a simple code able to evaluate the end time of a period of time, given as a number of minutes (it could be arbitrarily large). The start time is given as a pair of hours (0..23) and minutes (0..59). The result has to be printed to the console.
#
# For example, if an event starts at 12:17 and lasts 59 minutes, it will end at 13:16.
#
# Don't worry about any imperfections in your code ‒ it's okay if it accepts an invalid time ‒ the most important thing is that the code produces valid results for valid input data.
#
# Test your code carefully. Hint: using the % operator may be the key to success.

# %%
hour = int(input("Starting time (hours): "))
mins = int(input("Starting time (minutes): "))
dura = int(input("Event duration (minutes): "))
mins = mins + dura # find a total of all minutes
hour = hour + mins // 60 # find a number of hours hidden in minutes and update the hour
mins = mins % 60 # correct minutes to fall in the (0..59) range
hour = hour % 24 # correct hours to fall in the (0..23) range
print(hour, ":", mins, sep='')
# Out:
# Starting time (hours):  12
# Starting time (minutes):  10
# Event duration (minutes):  60
# 13:10
